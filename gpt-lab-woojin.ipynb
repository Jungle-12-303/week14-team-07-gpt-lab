# %% [markdown]
# # 과제 - PyTorch로 mini GPT 구현
#
# 이 노트북은 과제 안내서의 구현 순서를 그대로 따릅니다.
#
# 1. 환경설정
# 2. NSMC 데이터 준비
# 3. BPE 토크나이저
# 4. GPTDataset / InputEmbedding
# 5. MultiHeadAttention
# 6. GPTModel
# 7. 사전 학습 유틸리티
# 8. 감성 분류 미세 조정
#
# 각 단계의 `src/` TODO를 구현한 뒤, 바로 아래 pytest 셀로 해당 단계만 확인하세요.

# %% [markdown]
# ## 1. 환경설정
#
# Colab에서는 GitHub 저장소 URL과 GitHub Personal Access Token을 입력해 저장소를 clone하고 `src/`를 import 경로에 추가합니다.
# 로컬 VS Code에서는 현재 폴더를 프로젝트 루트로 보고 실행합니다.

# %%
# Colab: 이 셀을 가장 먼저 실행하세요.
import os
import subprocess
import sys
from pathlib import Path


def normalize_github_url(url: str) -> str:
    """Colab 입력값을 git clone에 사용할 수 있는 https URL로 정리합니다."""
    url = url.strip()
    if not url:
        raise ValueError("GitHub 저장소 URL을 입력해야 합니다.")
    if url.startswith("github.com/"):
        url = "https://" + url
    if not url.startswith("https://"):
        raise ValueError("저장소 URL은 https://github.com/... 또는 github.com/... 형식이어야 합니다.")
    url = url.rstrip("/")
    if not url.endswith(".git"):
        url += ".git"
    return url


if "google.colab" in sys.modules:
    from getpass import getpass

    repo_url = normalize_github_url(input("GitHub 저장소 URL (예: github.com/USERNAME/gpt-lab.git): "))
    token = getpass("GitHub Personal Access Token (Private 저장소인 경우 입력, 공개 저장소면 Enter): ").strip()
    clone_url = repo_url.replace("https://", f"https://{token}@") if token else repo_url
    repo_name = Path(repo_url[:-4]).name if repo_url.endswith(".git") else Path(repo_url).name
    repo_dir = Path("/content") / repo_name

    if not repo_dir.exists():
        subprocess.run(["git", "clone", clone_url, str(repo_dir)], check=True)
        subprocess.run(["git", "remote", "set-url", "origin", repo_url], cwd=repo_dir, check=True)
    else:
        print(f"이미 clone된 저장소를 사용합니다: {repo_dir}")

    os.chdir(repo_dir)
else:
    repo_dir = Path(".").resolve()

sys.path.insert(0, str(repo_dir / "src"))
print(f"Repo: {repo_dir}")
# Out:
# Repo: C:\week14-team-07-gpt-lab

# %%
# 단계별 테스트 실행 helper
import subprocess
import sys


def run_pytest(target: str):
    cmd = [sys.executable, "-m", "pytest", target, "-v"]
    print("실행 명령:", " ".join(cmd))
    result = subprocess.run(cmd, cwd=str(repo_dir), text=True, capture_output=True)
    print(result.stdout)
    if result.stderr:
        print(result.stderr)
    if result.returncode != 0:
        print("\n아직 통과하지 못한 테스트가 있습니다. 해당 단계의 TODO를 먼저 구현하세요.")
    else:
        print("\n선택한 테스트를 통과했습니다.")
    return result.returncode

# %% [markdown]
# ## 2. NSMC 데이터 준비
#
# 기본 데이터는 NAVER Sentiment Movie Corpus(NSMC)입니다.
# `download_data.py`는 원본 TSV를 내려받고, 사전 학습용 텍스트와 감성 분류용 JSONL을 만듭니다.

# %%
from pathlib import Path

try:
    import download_data

    paths = download_data.main()
except Exception as e:
    print("데이터 준비 중 문제가 생겼습니다:", e)
    print("이미 data/ 파일이 있다면 다음 셀부터 계속 진행할 수 있습니다.")

LM_TRAIN_PATH = repo_dir / "data" / "nsmc_lm_train.txt"
LM_VAL_PATH = repo_dir / "data" / "nsmc_lm_val.txt"
print("LM train exists:", LM_TRAIN_PATH.exists(), LM_TRAIN_PATH)
print("LM val exists:", LM_VAL_PATH.exists(), LM_VAL_PATH)
# Out:
# 이미 존재합니다: c:\week14-team-07-gpt-lab\data\ratings_train.txt
# 이미 존재합니다: c:\week14-team-07-gpt-lab\data\ratings_test.txt
# 사전 학습 train 텍스트: c:\week14-team-07-gpt-lab\data\nsmc_lm_train.txt (1,379,486자)
# 사전 학습 val 텍스트: c:\week14-team-07-gpt-lab\data\nsmc_lm_val.txt (120,560자)
# 감성 분류 train: c:\week14-team-07-gpt-lab\data\nsmc_sentiment_train.jsonl (137,996개)
# 감성 분류 val: c:\week14-team-07-gpt-lab\data\nsmc_sentiment_val.jsonl (11,999개)
# 감성 분류 test: c:\week14-team-07-gpt-lab\data\nsmc_sentiment_test.jsonl (49,997개)
# LM train exists: True C:\week14-team-07-gpt-lab\data\nsmc_lm_train.txt
# LM val exists: True C:\week14-team-07-gpt-lab\data\nsmc_lm_val.txt

# %%
corpus = LM_TRAIN_PATH.read_text(encoding="utf-8") if LM_TRAIN_PATH.exists() else ""
val_corpus = LM_VAL_PATH.read_text(encoding="utf-8") if LM_VAL_PATH.exists() else ""
print("train chars:", len(corpus))
print("val chars:", len(val_corpus))
print(corpus[:200])
# Out:
# train chars: 1379486
# val chars: 120560
# 개재미없다. 감독의 연출력의 한계
# 이제서야 보게된 대 명작 연출미가 정말 훌륭하다!!!!!!!!
# 소주미라클을 만들어라
# 귀여운 캐릭터들도 많이 나와서 보러 가야 겠어요..
# 블랙 코미디가 싫어요.
# 평점깎고싶다10글자
# TV시리즈가 너무재밌어서 영화는 기대안하고 봤는데 역시....최고네요
# 개인적 공감이 글쎄?
# 시작은 니시지마 때문에 봤는데 나름 괜찮은 영화 봤다고

# %% [markdown]
# ## 3. Step 1 - BPE 토크나이저
#
# 구현 파일: `src/bpe.py`
#
# 먼저 `pytest tests/test_bpe.py -v`를 통과시키세요. 한국어를 안전하게 다루기 위해 UTF-8 byte-level BPE로 구현해야 합니다.

# %%
run_pytest("tests/test_bpe.py")
# Out:
# 실행 명령: c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/test_bpe.py -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 6 items
#
# tests/test_bpe.py::TestSpecialTokens::test_special_ids_fixed PASSED      [ 16%]
# tests/test_bpe.py::TestBPETokenizer::test_init_special_tokens PASSED     [ 33%]
# tests/test_bpe.py::TestBPETokenizer::test_save_load_restores_vocab PASSED [ 50%]
# tests/test_bpe.py::TestBPETokenizer::test_encode_decode_restores_original_text PASSED [ 66%]
# tests/test_bpe.py::TestBPETokenizer::test_get_special_ids PASSED         [ 83%]
# tests/test_bpe.py::TestBPETrain::test_train_increases_vocab PASSED       [100%]
#
# ============================== 6 passed in 0.02s ==============================
#
#
# 선택한 테스트를 통과했습니다.
# 0

# %%
# BPE 구현 후 작은 말뭉치로 인코딩/디코딩 복원을 확인합니다.
try:
    from bpe import BPETokenizer

    tokenizer = BPETokenizer(vocab_size=300)
    tokenizer.train(corpus[:5000])
    sample = "이 영화는 정말 좋았다! English 123"
    ids = tokenizer.encode(sample, add_bos_eos=True)
    print(ids[:20])
    print(tokenizer.decode(ids))
except NotImplementedError as e:
    print("BPE TODO 미구현:", e)
# Out:
# [2, 265, 260, 291, 268, 260, 164, 153, 273, 148, 260, 166, 143, 281, 156, 270, 37, 36, 73, 114]
# 이 영화는 정말 좋았다! English 123

# %% [markdown]
# ## 4. Step 2 - GPTDataset / InputEmbedding
#
# 구현 파일: `src/dataset.py`, `src/embeddings.py`
#
# BPE가 통과한 뒤 데이터셋과 입력 임베딩을 구현합니다.

# %%
run_pytest("tests/test_dataset.py")
# Out:
# 실행 명령: c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/test_dataset.py -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 4 items
#
# tests/test_dataset.py::TestGPTDataset::test_dataset_length PASSED        [ 25%]
# tests/test_dataset.py::TestGPTDataset::test_dataset_getitem_shape PASSED [ 50%]
# tests/test_dataset.py::TestCreateDataloader::test_dataloader_batch_shape PASSED [ 75%]
# tests/test_dataset.py::TestInputEmbedding::test_input_embedding_shape PASSED [100%]
#
# ============================== 4 passed in 2.83s ==============================
#
#
# 선택한 테스트를 통과했습니다.
# 0

# %%
try:
    from bpe import BPETokenizer
    from dataset import create_dataloader
    from embeddings import InputEmbedding

    tokenizer = BPETokenizer(vocab_size=300)
    tokenizer.train(corpus[:5000])
    token_ids = tokenizer.encode(corpus[:5000])
    loader = create_dataloader(token_ids, context_length=32, batch_size=2, shuffle=False)
    inp, tgt = next(iter(loader))
    emb = InputEmbedding(vocab_size=300, emb_dim=32, context_length=32, drop_rate=0.0)
    out = emb(inp)
    print(inp.shape, tgt.shape, out.shape)
except NotImplementedError as e:
    print("Dataset/Embedding TODO 미구현:", e)
# Out:
# torch.Size([2, 32]) torch.Size([2, 32]) torch.Size([2, 32, 32])

# %% [markdown]
# ## 5. Step 3 - MultiHeadAttention
#
# 구현 파일: `src/attention.py`
#
# Q/K/V shape, head 분리, causal mask를 차례로 확인하세요.

# %%
run_pytest("tests/test_attention.py")
# Out:
# 실행 명령: c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/test_attention.py -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 2 items
#
# tests/test_attention.py::TestMultiHeadAttention::test_mha_output_shape PASSED [ 50%]
# tests/test_attention.py::TestMultiHeadAttention::test_mha_causal_mask_future_zero PASSED [100%]
#
# ============================== 2 passed in 1.98s ==============================
#
#
# 선택한 테스트를 통과했습니다.
# 0

# %% [markdown]
# ## 6. Step 4 - GPTModel
#
# 구현 파일: `src/model.py`
#
# LayerNorm, GELU, FeedForward, TransformerBlock, GPTModel, `generate_text_simple` 순서로 구현합니다.

# %%
run_pytest("tests/test_model.py")
# Out:
# 실행 명령: c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/test_model.py -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 7 items
#
# tests/test_model.py::TestLayerNorm::test_layernorm_shape PASSED          [ 14%]
# tests/test_model.py::TestGELU::test_gelu_shape PASSED                    [ 28%]
# tests/test_model.py::TestFeedForward::test_feedforward_shape PASSED      [ 42%]
# tests/test_model.py::TestTransformerBlock::test_transformer_block_shape PASSED [ 57%]
# tests/test_model.py::TestGPTModel::test_gpt_forward_shape PASSED         [ 71%]
# tests/test_model.py::TestGPTModel::test_gpt_forward_with_targets_returns_loss PASSED [ 85%]
# tests/test_model.py::TestGenerateTextSimple::test_generate_text_simple_shape PASSED [100%]
#
# ============================== 7 passed in 1.96s ==============================
#
#
# 선택한 테스트를 통과했습니다.
# 0

# %%
try:
    import torch
    from model import GPTModel

    config = {
        "vocab_size": 300,
        "context_length": 32,
        "emb_dim": 32,
        "n_heads": 4,
        "n_layers": 1,
        "drop_rate": 0.0,
        "qkv_bias": False,
    }
    model = GPTModel(config)
    x = torch.randint(0, config["vocab_size"], (2, 16))
    logits = model(x)
    print(logits.shape)
except NotImplementedError as e:
    print("Model TODO 미구현:", e)
# Out:
# torch.Size([2, 16, 300])

# %% [markdown]
# ## 7. Step 5 - 사전 학습 유틸리티
#
# 구현 파일: `src/train.py`
#
# loss 계산, checkpoint 저장/로드, temperature/top-k 생성, `train_model`을 구현합니다.

# %%
run_pytest("tests/test_train.py")
# Out:
# 실행 명령: c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/test_train.py -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 5 items
#
# tests/test_train.py::TestCalcLossBatch::test_calc_loss_batch_returns_scalar PASSED [ 20%]
# tests/test_train.py::TestCalcLossLoader::test_calc_loss_loader_returns_float PASSED [ 40%]
# tests/test_train.py::TestCheckpoint::test_save_load_checkpoint_restores_epoch_and_step PASSED [ 60%]
# tests/test_train.py::TestGenerate::test_generate_shape PASSED            [ 80%]
# tests/test_train.py::TestPlotLosses::test_plot_losses_callable PASSED    [100%]
#
# ============================== warnings summary ===============================
# tests/test_train.py::TestPlotLosses::test_plot_losses_callable
#   C:\week14-team-07-gpt-lab\src\train.py:556: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#     plt.show()
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================== 5 passed, 1 warning in 3.94s =========================
#
#
# 선택한 테스트를 통과했습니다.
# 0

# %% [markdown]
# ### AUTO TEST + AUTO TRAINING
#
# Run the code cell below. It runs pytest first, starts training only if tests pass, stops on possible overfitting, and saves best_checkpoint.pt.

# %%
from pathlib import Path
import sys

repo_dir = Path(".").resolve()
sys.path.insert(0, str(repo_dir / "src"))

from run_experiment import run_train_experiment

result = run_train_experiment(
    corpus=corpus,
    device="cpu",
    corpus_len=100000,
    output_dir=repo_dir / "train" / "train2" / "runs",
    run_name="woojin_notebook",
    vocab_size=2000,
    context_length=128,
    emb_dim=128,
    n_heads=2,
    n_layers=1,
    drop_rate=0.2,
    activation="relu",
    lr=2e-4,
    num_epochs=100,
    batch_size=32,
    weight_decay=0.01,
    patience=3,
    min_delta=0.0,
    eval_iter=4,
    run_tests=False,
    checkpoint_path=repo_dir / "best_checkpoint.pt",
)

model = result["model"]
tokenizer = result["tokenizer"]
config = result["config"]
history = result["history"]
# Out:
# Running tests before training:
# c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/test_bpe.py tests/test_dataset.py tests/test_attention.py tests/test_model.py tests/test_train.py -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 34 items
#
# tests/test_bpe.py::TestSpecialTokens::test_special_ids_fixed PASSED      [  2%]
# tests/test_bpe.py::TestBPETokenizer::test_init_special_tokens PASSED     [  5%]
# tests/test_bpe.py::TestBPETokenizer::test_save_load_restores_vocab PASSED [  8%]
# tests/test_bpe.py::TestBPETokenizer::test_encode_decode_restores_original_text PASSED [ 11%]
# tests/test_bpe.py::TestBPETokenizer::test_get_special_ids PASSED         [ 14%]
# tests/test_bpe.py::TestBPETrain::test_train_increases_vocab PASSED       [ 17%]
# tests/test_dataset.py::TestGPTDataset::test_dataset_length PASSED        [ 20%]
# tests/test_dataset.py::TestGPTDataset::test_dataset_getitem_shape PASSED [ 23%]
# tests/test_dataset.py::TestCreateDataloader::test_dataloader_batch_shape PASSED [ 26%]
# tests/test_dataset.py::TestInputEmbedding::test_input_embedding_shape PASSED [ 29%]
# tests/test_attention.py::TestMultiHeadAttention::test_mha_output_shape PASSED [ 32%]
# tests/test_attention.py::TestMultiHeadAttention::test_mha_causal_mask_future_zero PASSED [ 35%]
# tests/test_attention.py::TestMultiHeadAttention::test_mha_supports_attention_impl_options[manual] PASSED [ 38%]
# tests/test_attention.py::TestMultiHeadAttention::test_mha_supports_attention_impl_options[sdpa] PASSED [ 41%]
# tests/test_model.py::TestLayerNorm::test_layernorm_shape PASSED          [ 44%]
# tests/test_model.py::TestGELU::test_gelu_shape PASSED                    [ 47%]
# tests/test_model.py::TestFeedForward::test_feedforward_shape PASSED      [ 50%]
# tests/test_model.py::TestFeedForward::test_feedforward_supports_activation_options[gelu] PASSED [ 52%]
# tests/test_model.py::TestFeedForward::test_feedforward_supports_activation_options[gelu_exact] PASSED [ 55%]
# tests/test_model.py::TestFeedForward::test_feedforward_supports_activation_options[quick_gelu] PASSED [ 58%]
# tests/test_model.py::TestFeedForward::test_feedforward_supports_activation_options[silu] PASSED [ 61%]
# tests/test_model.py::TestFeedForward::test_feedforward_supports_activation_options[mish] PASSED [ 64%]
# tests/test_model.py::TestFeedForward::test_feedforward_supports_activation_options[squared_relu] PASSED [ 67%]
# tests/test_model.py::TestFeedForward::test_feedforward_supports_activation_options[swiglu] PASSED [ 70%]
# tests/test_model.py::TestTransformerBlock::test_transformer_block_shape PASSED [ 73%]
# tests/test_model.py::TestGPTModel::test_gpt_forward_shape PASSED         [ 76%]
# tests/test_model.py::TestGPTModel::test_gpt_forward_with_targets_returns_loss PASSED [ 79%]
# tests/test_model.py::TestGPTModel::test_gpt_supports_tied_embeddings PASSED [ 82%]
# tests/test_model.py::TestGenerateTextSimple::test_generate_text_simple_shape PASSED [ 85%]
# tests/test_train.py::TestCalcLossBatch::test_calc_loss_batch_returns_scalar PASSED [ 88%]
# tests/test_train.py::TestCalcLossLoader::test_calc_loss_loader_returns_float PASSED [ 91%]
# tests/test_train.py::TestCheckpoint::test_save_load_checkpoint_restores_epoch_and_step PASSED [ 94%]
# tests/test_train.py::TestGenerate::test_generate_shape PASSED            [ 97%]
# tests/test_train.py::TestPlotLosses::test_plot_losses_callable PASSED    [100%]
#
# ============================== warnings summary ===============================
# tests/test_train.py::TestPlotLosses::test_plot_losses_callable
#   C:\week14-team-07-gpt-lab\src\train.py:609: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#     plt.show()
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================== 34 passed, 1 warning in 6.96s ========================
#
# pytest passed. Starting training.
# Epoch 01: train_loss=8.1814, val_loss=8.1258, gap=-0.0556, overfit_count=0
# Epoch 02: train_loss=8.1469, val_loss=8.1198, gap=-0.0271, overfit_count=0
# Epoch 03: train_loss=8.1100, val_loss=8.1137, gap=0.0037, overfit_count=0
# Epoch 04: train_loss=8.0837, val_loss=8.1075, gap=0.0239, overfit_count=0
# Epoch 05: train_loss=8.0444, val_loss=8.1011, gap=0.0567, overfit_count=0
# Epoch 06: train_loss=8.0089, val_loss=8.0943, gap=0.0854, overfit_count=0
# Epoch 07: train_loss=7.9848, val_loss=8.0872, gap=0.1024, overfit_count=0
# Epoch 08: train_loss=7.9446, val_loss=8.0795, gap=0.1349, overfit_count=0
# Epoch 09: train_loss=7.9216, val_loss=8.0714, gap=0.1498, overfit_count=0
# Epoch 10: train_loss=7.8809, val_loss=8.0628, gap=0.1819, overfit_count=0
# Epoch 11: train_loss=7.8397, val_loss=8.0535, gap=0.2139, overfit_count=0
# Epoch 12: train_loss=7.8036, val_loss=8.0437, gap=0.2401, overfit_count=0
# Epoch 13: train_loss=7.7723, val_loss=8.0333, gap=0.2610, overfit_count=0
# Epoch 14: train_loss=7.7382, val_loss=8.0221, gap=0.2839, overfit_count=0
# Epoch 15: train_loss=7.6917, val_loss=8.0103, gap=0.3187, overfit_count=0
# Epoch 16: train_loss=7.6543, val_loss=7.9978, gap=0.3434, overfit_count=0
# Epoch 17: train_loss=7.6169, val_loss=7.9844, gap=0.3675, overfit_count=0
# Epoch 18: train_loss=7.5761, val_loss=7.9703, gap=0.3941, overfit_count=0
# Epoch 19: train_loss=7.5375, val_loss=7.9555, gap=0.4180, overfit_count=0
# Epoch 20: train_loss=7.4934, val_loss=7.9400, gap=0.4466, overfit_count=0
# Epoch 21: train_loss=7.4511, val_loss=7.9238, gap=0.4727, overfit_count=0
# Epoch 22: train_loss=7.4095, val_loss=7.9069, gap=0.4974, overfit_count=0
# Epoch 23: train_loss=7.3590, val_loss=7.8894, gap=0.5305, overfit_count=0
# Epoch 24: train_loss=7.3167, val_loss=7.8715, gap=0.5547, overfit_count=0
# Epoch 25: train_loss=7.2675, val_loss=7.8530, gap=0.5855, overfit_count=0
# Epoch 26: train_loss=7.2274, val_loss=7.8342, gap=0.6068, overfit_count=0
# Epoch 27: train_loss=7.1677, val_loss=7.8151, gap=0.6474, overfit_count=0
# Epoch 28: train_loss=7.1362, val_loss=7.7959, gap=0.6597, overfit_count=0
# Epoch 29: train_loss=7.0833, val_loss=7.7766, gap=0.6933, overfit_count=0
# Epoch 30: train_loss=7.0327, val_loss=7.7573, gap=0.7246, overfit_count=0
# Epoch 31: train_loss=6.9917, val_loss=7.7381, gap=0.7464, overfit_count=0
# Epoch 32: train_loss=6.9515, val_loss=7.7192, gap=0.7677, overfit_count=0
# Epoch 33: train_loss=6.8997, val_loss=7.7007, gap=0.8010, overfit_count=0
# Epoch 34: train_loss=6.8526, val_loss=7.6826, gap=0.8300, overfit_count=0
# Epoch 35: train_loss=6.8131, val_loss=7.6651, gap=0.8520, overfit_count=0
# Epoch 36: train_loss=6.7636, val_loss=7.6481, gap=0.8845, overfit_count=0
# Epoch 37: train_loss=6.7120, val_loss=7.6319, gap=0.9199, overfit_count=0
# Epoch 38: train_loss=6.6843, val_loss=7.6164, gap=0.9321, overfit_count=0
# Epoch 39: train_loss=6.6239, val_loss=7.6018, gap=0.9779, overfit_count=0
# Epoch 40: train_loss=6.5933, val_loss=7.5881, gap=0.9947, overfit_count=0
# Epoch 41: train_loss=6.5536, val_loss=7.5753, gap=1.0217, overfit_count=0
# Epoch 42: train_loss=6.5133, val_loss=7.5634, gap=1.0502, overfit_count=0
# Epoch 43: train_loss=6.4709, val_loss=7.5526, gap=1.0817, overfit_count=0
# Epoch 44: train_loss=6.4446, val_loss=7.5428, gap=1.0981, overfit_count=0
# Epoch 45: train_loss=6.3966, val_loss=7.5340, gap=1.1374, overfit_count=0
# Epoch 46: train_loss=6.3696, val_loss=7.5262, gap=1.1567, overfit_count=0
# Epoch 47: train_loss=6.3353, val_loss=7.5194, gap=1.1841, overfit_count=0
# Epoch 48: train_loss=6.2945, val_loss=7.5134, gap=1.2189, overfit_count=0
# Epoch 49: train_loss=6.2601, val_loss=7.5083, gap=1.2482, overfit_count=0
# Epoch 50: train_loss=6.2331, val_loss=7.5040, gap=1.2708, overfit_count=0
# Epoch 51: train_loss=6.1951, val_loss=7.5004, gap=1.3052, overfit_count=0
# Epoch 52: train_loss=6.1802, val_loss=7.4974, gap=1.3172, overfit_count=0
# Epoch 53: train_loss=6.1429, val_loss=7.4952, gap=1.3523, overfit_count=0
# Epoch 54: train_loss=6.1111, val_loss=7.4935, gap=1.3824, overfit_count=0
# Epoch 55: train_loss=6.0803, val_loss=7.4922, gap=1.4120, overfit_count=0
# Epoch 56: train_loss=6.0492, val_loss=7.4914, gap=1.4422, overfit_count=0
# Epoch 57: train_loss=6.0275, val_loss=7.4909, gap=1.4635, overfit_count=0
# Epoch 58: train_loss=6.0022, val_loss=7.4908, gap=1.4886, overfit_count=0
# Epoch 59: train_loss=5.9764, val_loss=7.4909, gap=1.5145, overfit_count=1
# Epoch 60: train_loss=5.9418, val_loss=7.4912, gap=1.5494, overfit_count=2
# epoch | train_loss | val_loss | gap | overfit_count
# ----- | ---------- | -------- | --- | -------------
#     1 | 8.1814 | 8.1258 | -0.0556 | 0
#     2 | 8.1469 | 8.1198 | -0.0271 | 0
#     3 | 8.1100 | 8.1137 | 0.0037 | 0
#     4 | 8.0837 | 8.1075 | 0.0239 | 0
#     5 | 8.0444 | 8.1011 | 0.0567 | 0
#     6 | 8.0089 | 8.0943 | 0.0854 | 0
#     7 | 7.9848 | 8.0872 | 0.1024 | 0
#     8 | 7.9446 | 8.0795 | 0.1349 | 0
#     9 | 7.9216 | 8.0714 | 0.1498 | 0
#    10 | 7.8809 | 8.0628 | 0.1819 | 0
#    11 | 7.8397 | 8.0535 | 0.2139 | 0
#    12 | 7.8036 | 8.0437 | 0.2401 | 0
#    13 | 7.7723 | 8.0333 | 0.2610 | 0
#    14 | 7.7382 | 8.0221 | 0.2839 | 0
#    15 | 7.6917 | 8.0103 | 0.3187 | 0
#    16 | 7.6543 | 7.9978 | 0.3434 | 0
#    17 | 7.6169 | 7.9844 | 0.3675 | 0
#    18 | 7.5761 | 7.9703 | 0.3941 | 0
#    19 | 7.5375 | 7.9555 | 0.4180 | 0
#    20 | 7.4934 | 7.9400 | 0.4466 | 0
#    21 | 7.4511 | 7.9238 | 0.4727 | 0
#    22 | 7.4095 | 7.9069 | 0.4974 | 0
#    23 | 7.3590 | 7.8894 | 0.5305 | 0
#    24 | 7.3167 | 7.8715 | 0.5547 | 0
#    25 | 7.2675 | 7.8530 | 0.5855 | 0
#    26 | 7.2274 | 7.8342 | 0.6068 | 0
#    27 | 7.1677 | 7.8151 | 0.6474 | 0
#    28 | 7.1362 | 7.7959 | 0.6597 | 0
#    29 | 7.0833 | 7.7766 | 0.6933 | 0
#    30 | 7.0327 | 7.7573 | 0.7246 | 0
#    31 | 6.9917 | 7.7381 | 0.7464 | 0
#    32 | 6.9515 | 7.7192 | 0.7677 | 0
#    33 | 6.8997 | 7.7007 | 0.8010 | 0
#    34 | 6.8526 | 7.6826 | 0.8300 | 0
#    35 | 6.8131 | 7.6651 | 0.8520 | 0
#    36 | 6.7636 | 7.6481 | 0.8845 | 0
#    37 | 6.7120 | 7.6319 | 0.9199 | 0
#    38 | 6.6843 | 7.6164 | 0.9321 | 0
#    39 | 6.6239 | 7.6018 | 0.9779 | 0
#    40 | 6.5933 | 7.5881 | 0.9947 | 0
#    41 | 6.5536 | 7.5753 | 1.0217 | 0
#    42 | 6.5133 | 7.5634 | 1.0502 | 0
#    43 | 6.4709 | 7.5526 | 1.0817 | 0
#    44 | 6.4446 | 7.5428 | 1.0981 | 0
#    45 | 6.3966 | 7.5340 | 1.1374 | 0
#    46 | 6.3696 | 7.5262 | 1.1567 | 0
#    47 | 6.3353 | 7.5194 | 1.1841 | 0
#    48 | 6.2945 | 7.5134 | 1.2189 | 0
#    49 | 6.2601 | 7.5083 | 1.2482 | 0
#    50 | 6.2331 | 7.5040 | 1.2708 | 0
#    51 | 6.1951 | 7.5004 | 1.3052 | 0
#    52 | 6.1802 | 7.4974 | 1.3172 | 0
#    53 | 6.1429 | 7.4952 | 1.3523 | 0
#    54 | 6.1111 | 7.4935 | 1.3824 | 0
#    55 | 6.0803 | 7.4922 | 1.4120 | 0
#    56 | 6.0492 | 7.4914 | 1.4422 | 0
#    57 | 6.0275 | 7.4909 | 1.4635 | 0
#    58 | 6.0022 | 7.4908 | 1.4886 | 0
#    59 | 5.9764 | 7.4909 | 1.5145 | 1
#    60 | 5.9418 | 7.4912 | 1.5494 | 2
# experiment | hypothesis | expected
# ---------- | ---------- | --------
# vocab_size 3000 -> 1000/2000 | A smaller corpus may train more stably with fewer BPE tokens. | Fewer broken-looking generations and faster token learning.
# n_layers 1 -> 2 | One transformer block may be too weak for language patterns. | Lower validation loss if overfitting is controlled.
# n_heads 1 -> 2/4 | More heads can split attention into different relation types. | Better context use when emb_dim is large enough.
# dropout 0.0 -> 0.1 | No dropout can overfit small corpora quickly. | Validation loss may become more stable.
# corpus_len 10000 -> 50000+ | The model needs more examples to learn Korean byte/BPE patterns. | Better generation quality and lower validation loss.
# learning_rate 3e-4 -> 1e-4/5e-4 | The chosen learning rate may be too slow or too unstable. | Find a setting where train and validation loss decrease together.
# Stopped reason: max_epochs completed
# Best val loss: 7.4908 at epoch 58

# %% [markdown]
# ### LOSS GRAPH
#
# Run this after AUTO TEST + AUTO TRAINING to compare train loss, validation loss, and the validation-train gap by epoch.

# %%
import matplotlib.pyplot as plt

epochs = [row["epoch"] for row in history]
train_losses = [row["train_loss"] for row in history]
val_losses = [row["val_loss"] for row in history]
gaps = [row["gap"] for row in history]

plt.figure(figsize=(10, 4))
plt.plot(epochs, train_losses, marker="o", label="train loss")
plt.plot(epochs, val_losses, marker="o", label="val loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Train / Validation Loss")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

plt.figure(figsize=(10, 3))
plt.plot(epochs, gaps, marker="o", color="tomato", label="val - train gap")
plt.xlabel("epoch")
plt.ylabel("gap")
plt.title("Overfit Gap")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
# 모든 앞 단계가 구현된 뒤 한 배치 smoke test를 실행합니다.
try:
    import torch
    from bpe import BPETokenizer
    from dataset import create_dataloader
    from model import GPTModel
    from train import calc_loss_batch

    smoke_tokenizer = BPETokenizer(vocab_size=300)
    smoke_tokenizer.train(corpus[:5000])
    smoke_token_ids = smoke_tokenizer.encode(corpus[:5000])
    smoke_loader = create_dataloader(smoke_token_ids, context_length=32, batch_size=2, shuffle=False)
    inp, tgt = next(iter(smoke_loader))
    smoke_config = {
        "vocab_size": 300,
        "context_length": 32,
        "emb_dim": 32,
        "n_heads": 4,
        "n_layers": 1,
        "drop_rate": 0.0,
        "qkv_bias": False,
    }
    smoke_model = GPTModel(smoke_config)
    loss = calc_loss_batch(inp, tgt, smoke_model, torch.device("cpu"))
    loss.backward()
    print("smoke loss:", loss.item())
except NotImplementedError as e:
    print("사전 학습 TODO 미구현:", e)
# Out:
# smoke loss: 6.008306503295898

# %%
import torch
import train
import importlib

importlib.reload(train)

from train import generate

if "result" not in globals():
    raise RuntimeError("Run AUTO TEST + AUTO TRAINING first.")

model = result["model"]
tokenizer = result["tokenizer"]
config = result["config"]

device = next(model.parameters()).device

text = "이 영화는 정말 재미가 있"
idx = torch.tensor(
    tokenizer.encode(text),
    dtype=torch.long,
    device=device,
).unsqueeze(0)

out = generate(
    model=model,
    idx=idx,
    max_new_tokens=20,
    context_size=config["context_length"],
    temperature=0.5,
    top_k=10,
    eos_id=tokenizer.get_eos_id(),
)

print(tokenizer.decode(out[0].tolist(), skip_special=True))
# Out:
# 이 영화는 정말 재미가 있만는가�이 �0하나이 �는이는이 �이 는는이

# %% [markdown]
# ## 8. Step 6 - 감성 분류 미세 조정
#
# 구현 파일: `src/finetune.py`
#
# NSMC JSONL/TSV를 읽어 분류 Dataset을 만들고, GPT backbone 위에 classification head를 붙입니다.

# %%
run_pytest("tests/test_finetune.py")
# Out:
# 실행 명령: c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/test_finetune.py -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 4 items
#
# tests/test_finetune.py::TestMakeSentimentDataset::test_make_sentiment_dataset_splits_rows PASSED [ 25%]
# tests/test_finetune.py::TestReviewSentimentDataset::test_review_sentiment_dataset_getitem PASSED [ 50%]
# tests/test_finetune.py::TestGPTForSequenceClassification::test_sequence_classification_shape PASSED [ 75%]
# tests/test_finetune.py::TestSentimentTrainEval::test_train_eval_functions_exist PASSED [100%]
#
# ============================== 4 passed in 1.97s ==============================
#
#
# 선택한 테스트를 통과했습니다.
# 0

# %% [markdown]
# ## 9. 전체 테스트와 제출 전 확인
#
# 각 단계 테스트가 모두 통과하면 마지막에 전체 테스트를 실행합니다.

# %%
run_pytest("tests/")
# Out:
# 실행 명령: c:\Users\82103\anaconda3\envs\gpt-lab\python.exe -m pytest tests/ -v
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\82103\anaconda3\envs\gpt-lab\python.exe
# cachedir: .pytest_cache
# rootdir: C:\week14-team-07-gpt-lab
# collecting ... collected 28 items
#
# tests/test_attention.py::TestMultiHeadAttention::test_mha_output_shape PASSED [  3%]
# tests/test_attention.py::TestMultiHeadAttention::test_mha_causal_mask_future_zero PASSED [  7%]
# tests/test_bpe.py::TestSpecialTokens::test_special_ids_fixed PASSED      [ 10%]
# tests/test_bpe.py::TestBPETokenizer::test_init_special_tokens PASSED     [ 14%]
# tests/test_bpe.py::TestBPETokenizer::test_save_load_restores_vocab PASSED [ 17%]
# tests/test_bpe.py::TestBPETokenizer::test_encode_decode_restores_original_text PASSED [ 21%]
# tests/test_bpe.py::TestBPETokenizer::test_get_special_ids PASSED         [ 25%]
# tests/test_bpe.py::TestBPETrain::test_train_increases_vocab PASSED       [ 28%]
# tests/test_dataset.py::TestGPTDataset::test_dataset_length PASSED        [ 32%]
# tests/test_dataset.py::TestGPTDataset::test_dataset_getitem_shape PASSED [ 35%]
# tests/test_dataset.py::TestCreateDataloader::test_dataloader_batch_shape PASSED [ 39%]
# tests/test_dataset.py::TestInputEmbedding::test_input_embedding_shape PASSED [ 42%]
# tests/test_finetune.py::TestMakeSentimentDataset::test_make_sentiment_dataset_splits_rows PASSED [ 46%]
# tests/test_finetune.py::TestReviewSentimentDataset::test_review_sentiment_dataset_getitem PASSED [ 50%]
# tests/test_finetune.py::TestGPTForSequenceClassification::test_sequence_classification_shape PASSED [ 53%]
# tests/test_finetune.py::TestSentimentTrainEval::test_train_eval_functions_exist PASSED [ 57%]
# tests/test_model.py::TestLayerNorm::test_layernorm_shape PASSED          [ 60%]
# tests/test_model.py::TestGELU::test_gelu_shape PASSED                    [ 64%]
# tests/test_model.py::TestFeedForward::test_feedforward_shape PASSED      [ 67%]
# tests/test_model.py::TestTransformerBlock::test_transformer_block_shape PASSED [ 71%]
# tests/test_model.py::TestGPTModel::test_gpt_forward_shape PASSED         [ 75%]
# tests/test_model.py::TestGPTModel::test_gpt_forward_with_targets_returns_loss PASSED [ 78%]
# tests/test_model.py::TestGenerateTextSimple::test_generate_text_simple_shape PASSED [ 82%]
# tests/test_train.py::TestCalcLossBatch::test_calc_loss_batch_returns_scalar PASSED [ 85%]
# tests/test_train.py::TestCalcLossLoader::test_calc_loss_loader_returns_float PASSED [ 89%]
# tests/test_train.py::TestCheckpoint::test_save_load_checkpoint_restores_epoch_and_step PASSED [ 92%]
# tests/test_train.py::TestGenerate::test_generate_shape PASSED            [ 96%]
# tests/test_train.py::TestPlotLosses::test_plot_losses_callable PASSED    [100%]
#
# ============================== warnings summary ===============================
# tests/test_train.py::TestPlotLosses::test_plot_losses_callable
#   C:\week14-team-07-gpt-lab\src\train.py:553: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#     plt.show()
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================== 28 passed, 1 warning in 5.01s ========================
#
#
# 선택한 테스트를 통과했습니다.
# 0
